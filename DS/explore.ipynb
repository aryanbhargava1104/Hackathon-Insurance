# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./input/Final_insurance_fraud.csv")
df
# Out:
#      Claim_ID  Customer_Age  Claim_Amount  Claim_History Policy_Type  \
# 0     C100000          58.0       20604.0            0.0        Auto
# 1     C100001          71.0       17923.0            0.0        Auto
# 2     C100002          48.0       48591.0            4.0      Health
# 3     C100003          34.0        9547.0            2.0        Home
# 4     C100004          62.0       45283.0            1.0        Auto
# ...       ...           ...           ...            ...         ...
# 5056      NaN           NaN           NaN            NaN         NaN
# 5057      NaN           NaN           NaN            NaN         NaN
# 5058      NaN           NaN           NaN            NaN         NaN
# 5059      NaN           NaN           NaN            NaN         NaN
# 5060      NaN           NaN           NaN            NaN         NaN
#
#      Incident_Severity  Claim_Frequency  Fraud_Label  \
# 0               Severe              3.0          0.0
# ...

# %%
df.columns
# Out:
# Index(['Claim_ID', 'Customer_Age', 'Claim_Amount', 'Claim_History',
#        'Policy_Type', 'Incident_Severity', 'Claim_Frequency', 'Fraud_Label',
#        'Claim_Description', 'Gender', 'Marital Status', 'Occupation',
#        'Income Level', 'Education Level', 'Location', 'Behavioral Data',
#        'Purchase History', 'Policy Start Date', 'Policy Renewal Date',
#        'Interactions with Customer Service', 'Insurance Products Owned',
#        'Coverage Amount', 'Premium Amount', 'Deductible', 'Policy Type',
#        'Customer Preferences', 'Preferred Communication Channel',
#        'Driving Record', 'Life Events'],
#       dtype='object')

# %%
df["Fraud_Label"].value_counts()
# Out:
# Fraud_Label
# 0.0    4228
# 1.0     760
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Claim_ID                              69
# Customer_Age                          70
# Claim_Amount                          81
# Claim_History                         70
# Policy_Type                           75
# Incident_Severity                     75
# Claim_Frequency                       81
# Fraud_Label                           73
# Claim_Description                     73
# Gender                                 0
# Marital Status                         0
# Occupation                             0
# Income Level                           0
# Education Level                        0
# Location                               0
# Behavioral Data                        0
# Purchase History                       0
# Policy Start Date                      0
# Policy Renewal Date                    0
# Interactions with Customer Service     0
# Insurance Products Owned               0
# Coverage Amount                        0
# Premium Amount                         0
# ...

# %%
test_df = df[df["Fraud_Label"].isna()].drop(columns=["Fraud_Label"])
test_df.isna().sum()
# Out:
# Claim_ID                              61
# Customer_Age                          61
# Claim_Amount                          61
# Claim_History                         61
# Policy_Type                           67
# Incident_Severity                     67
# Claim_Frequency                       73
# Claim_Description                     73
# Gender                                 0
# Marital Status                         0
# Occupation                             0
# Income Level                           0
# Education Level                        0
# Location                               0
# Behavioral Data                        0
# Purchase History                       0
# Policy Start Date                      0
# Policy Renewal Date                    0
# Interactions with Customer Service     0
# Insurance Products Owned               0
# Coverage Amount                        0
# Premium Amount                         0
# Deductible                             0
# ...

# %%
df = df.dropna(subset=["Fraud_Label"])
df.isna().sum()
# Out:
# Claim_ID                               8
# Customer_Age                           9
# Claim_Amount                          20
# Claim_History                          9
# Policy_Type                            8
# Incident_Severity                      8
# Claim_Frequency                        8
# Fraud_Label                            0
# Claim_Description                      0
# Gender                                 0
# Marital Status                         0
# Occupation                             0
# Income Level                           0
# Education Level                        0
# Location                               0
# Behavioral Data                        0
# Purchase History                       0
# Policy Start Date                      0
# Policy Renewal Date                    0
# Interactions with Customer Service     0
# Insurance Products Owned               0
# Coverage Amount                        0
# Premium Amount                         0
# ...

# %%
df.to_csv("./input/train.csv", index=False)
test_df.to_csv("./input/test.csv", index=False)

# %%
df["Fraud_Label"].value_counts()
# Out:
# Fraud_Label
# 0.0    4228
# 1.0     760
# Name: count, dtype: int64

# %%
df["Preferred Communication Channel"].value_counts()
# Out:
# Preferred Communication Channel
# In-Person Meeting    1367
# Phone                1091
# Mail                  974
# Email                 825
# Text                  731
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Claim_ID', 'Customer_Age', 'Claim_Amount', 'Claim_History',
#        'Policy_Type', 'Incident_Severity', 'Claim_Frequency', 'Fraud_Label',
#        'Claim_Description', 'Gender', 'Marital Status', 'Occupation',
#        'Income Level', 'Education Level', 'Location', 'Behavioral Data',
#        'Purchase History', 'Policy Start Date', 'Policy Renewal Date',
#        'Interactions with Customer Service', 'Insurance Products Owned',
#        'Coverage Amount', 'Premium Amount', 'Deductible', 'Policy Type',
#        'Customer Preferences', 'Preferred Communication Channel',
#        'Driving Record', 'Life Events'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4988 entries, 0 to 4987
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Claim_ID                            4980 non-null   object
#  1   Customer_Age                        4979 non-null   float64
#  2   Claim_Amount                        4968 non-null   float64
#  3   Claim_History                       4979 non-null   float64
#  4   Policy_Type                         4980 non-null   object
#  5   Incident_Severity                   4980 non-null   object
#  6   Claim_Frequency                     4980 non-null   float64
#  7   Fraud_Label                         4988 non-null   float64
#  8   Claim_Description                   4988 non-null   object
#  9   Gender                              4988 non-null   object
#  10  Marital Status                      4988 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   Claim_ID  Customer_Age  Claim_Amount  Claim_History Policy_Type  \
# 0  C100000          58.0       20604.0            0.0        Auto
# 1  C100001          71.0       17923.0            0.0        Auto
# 2  C100002          48.0       48591.0            4.0      Health
# 3  C100003          34.0        9547.0            2.0        Home
# 4  C100004          62.0       45283.0            1.0        Auto
#
#   Incident_Severity  Claim_Frequency  Fraud_Label  \
# 0            Severe              3.0          0.0
# 1          Moderate              3.0          0.0
# 2            Severe              9.0          0.0
# 3            Severe              1.0          0.0
# 4            Severe              7.0          0.0
#
#                                    Claim_Description  Gender Marital Status  \
# 0  Enjoy four run family hundred number. Say mana...  Female        Married
# 1  Peace play attention he box information agree....    Male        Widowed
# ...

# %%
df.columns
# Out:
# Index(['Claim_ID', 'Customer_Age', 'Claim_Amount', 'Claim_History',
#        'Policy_Type', 'Incident_Severity', 'Claim_Frequency', 'Fraud_Label',
#        'Claim_Description', 'Gender', 'Marital Status', 'Occupation',
#        'Income Level', 'Education Level', 'Location', 'Behavioral Data',
#        'Purchase History', 'Policy Start Date', 'Policy Renewal Date',
#        'Interactions with Customer Service', 'Insurance Products Owned',
#        'Coverage Amount', 'Premium Amount', 'Deductible', 'Policy Type',
#        'Customer Preferences', 'Preferred Communication Channel',
#        'Driving Record', 'Life Events'],
#       dtype='object')
